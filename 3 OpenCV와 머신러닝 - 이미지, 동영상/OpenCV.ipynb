# %% [markdown]
# # 이미지 읽기

# %%
# 이미지 다운로드
import urllib.request as req
url = "http://uta.pw/shodou/img/28/214.png"
req.urlretrieve(url, "test.png")
# Out:
# ('test.png', <http.client.HTTPMessage at 0x1f8aa939d08>)

# %%
# openCV로 읽어드이기
import cv2
img = cv2.imread("test.png")
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
# 이미지가 없으면 None을 반환
img2 = cv2.imread("존재하지 않는 파일.png")
print(img2)
# Out:
# None

# %% [markdown]
# # 이미지 인라인 출력하기

# %%
# %matplotlib inline

# %%
# 다운로드한 이미지 출력하기
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("test.png")
plt.axis("off")  # 격자와 숫자 제거
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 이미지 저장하기

# %%
import cv2

# 이미지 읽어들이기
img = cv2.imread("test.png")

# 이미지 저장하기
cv2.imwrite("out.png", img)
# Out:
# True

# %% [markdown]
# # 이미지 크기 변경과 자르기

# %%
import matplotlib.pyplot as plt
import cv2

# 이미지 읽어들이기
img = cv2.imread("test.png")
#이미지 크기변경
# cv2.resize(<img>, (<width>, <height>))
im2 = cv2.resize(img, (600,300))
cv2.imwrite("out-resize.png", im2)

#이미지 출력하기
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 이미지 자르기

# %%
import matplotlib.pyplot as plt
import cv2

# 이미지 읽어들이기
img = cv2.imread("test.png")
#이미지 자르기
im2 = img[150:450, 150:450]
#이미지 크기변경
im2 = cv2.resize(im2, (400,400))
#저장하기
cv2.imwrite("cut-resize.png", im2)

#이미지 출력하기
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # OpenCV 이미지 좌표계
# ## 일반적인 이미지 처리와 같은 좌표계를 사용
# ### 왼쪽 맨 위가 (0, 0)이며 오른쪽 아래로 갈수록 값이 커진다.
